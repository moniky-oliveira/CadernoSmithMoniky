# %%
import panel as pn
pn.extension(comms='colab')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='def20431-8325-4271-87b7-320508a1a7c9'>
#   <div id="d5785029-6a0a-4075-89cd-26d1cc109b0c" data-root-id="def20431-8325-4271-87b7-320508a1a7c9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Números de Smith
# ## Explorando relações e padrões numéricos

# %% [markdown]
# # Sumário
#
# - <a href="#investigacao">Investigação Inicial</a>
#
# - <a href="#historia">História dos Números de Smith</a>
#
# - <a href="#video">Vídeo</a>
#
# - <a href="#exercicios">Exercícios Básicos</a>
#
# - <a href="#conceitos">Conceitos Fundamentais</a>
#
# - <a href="#interativos">Exercícios Interativos</a>
#
# - <a href="#compartilhe">Compartilhe sua ideia</a>
#
# - <a href="#complementar">Materiais Complementares</a>
#
# - <a href="#referencia">Referencias</a>

# %% [markdown]
# <h1 id="investigacao">Investigação Inicial</h1>

# %% [markdown]
# Observe o número 666 e sua fatoração em números primos.
#
# | Número | Fatoração |
# |:------:|:---------:|
# | 666  | 2 x 3² x 37     |
#
# - O que você percebe?
# - Existe alguma relação entre os algarismos do número e dos fatores primos?
#
# <details>
# <summary style="font-size:18px; color:#0B3B70;">
# <b>Ver resposta</b>
# </summary>
#
# <div style="
# margin-top:10px;
# padding:15px;
# background:#eef6ff;
# border-left:5px solid #0B3B70;
# border-radius:8px;
# ">
#
# A relação encontrada é que:
#
# <ul>
# <li>A soma dos algarismos do número (6+6+6) é 18.</li>
# <li>A soma dos algarismos de seus fatores primos (2+3+3+3+7) também é 18.</li>
# </ul>
# </div>
# </details>

# %% [markdown]
# <h1 id="historia">História dos Números de Smith</h1>

# %% [markdown]
# Na Matemática, muitas descobertas começaram justamente com uma simples observação do cotidiano. Um exemplo disso ocorreu em 1982, quando o matemático canadense-americano Albert Wilansky observou o número de telefone de seu cunhado, Harold Smith: 493-7775. Ele notou que ao fatorar este número, a soma dos algarismos do número se igualava a soma dos algarismos de seus fatores primos.
#
# <figure style="text-align:center;">
#     <img src="C:\Users\Jean\Desktop\jupyter book/Apresenta1.jpg" width="700">
# </figure>
#
# Wilansky cunhou o termo "número de Smith" em homenagem a Harold Smith. Essa observação deu origem ao estudo dessa classe especial de números.

# %% [markdown]
# Abaixo temos uma tabela com os cinco primeiros números com essa mesma propriedade.
#
# | Número | Soma dos algarismos | Fatoração | Soma dos algarismos da fatoração |
# |:------:|:-------------------:|:---------:|:-------------------:|
# | 4      | 4                   | 2 x 2     | 4                   |
# | 22     | 4                   | 2 x 11    | 4                   |
# | 27     | 9                   | 3 x 3 x 3 | 9                   |
# | 58     | 13                  | 2 x 29    | 13                  |
# | 85     | 13                  | 5 x 17    | 13                  |

# %% [markdown]
# <h1 id="video">Vídeo</h1>

# %% [markdown]
# <h1 id="exercicios">Exercícios Básicos</h1>

# %% [markdown]
# Verifique os seguintes números:

# %%
import ipywidgets as widgets
from IPython.display import display

pergunta = widgets.HTML(
    value="<b>121 é um Número de Smith?</b>"
)

sim = widgets.Button(description="Sim")
nao = widgets.Button(description="Não")

resultado = widgets.HTML()

def resposta_sim(b):
    resultado.value = "<span style='color:green'><b>Correto!</b></span>"

def resposta_nao(b):
    resultado.value = "<span style='color:red'><b>Errado!</b></span>"

sim.on_click(resposta_sim)
nao.on_click(resposta_nao)

display(widgets.HBox([pergunta, sim, nao]))
display(resultado)
# Out:
# ...
# HTML(value='')

# %%
import ipywidgets as widgets
from IPython.display import display

pergunta = widgets.HTML(
    value="<b>198 é um Número de Smith?</b>"
)

sim = widgets.Button(description="Sim")
nao = widgets.Button(description="Não")

resultado = widgets.HTML()

def resposta_nao(b):
    resultado.value = "<span style='color:green'><b>Correto!</b></span>"

def resposta_sim(b):
    resultado.value = "<span style='color:red'><b>Errado!</b></span>"

sim.on_click(resposta_sim)
nao.on_click(resposta_nao)

display(widgets.HBox([pergunta, sim, nao]))
display(resultado)
# Out:
# ...
# HTML(value='')

# %%
import ipywidgets as widgets
from IPython.display import display

pergunta = widgets.HTML(
    value="<b>250 é um Número de Smith?</b>"
)

sim = widgets.Button(description="Sim")
nao = widgets.Button(description="Não")

resultado = widgets.HTML()

def resposta_nao(b):
    resultado.value = "<span style='color:green'><b>Correto!</b></span>"

def resposta_sim(b):
    resultado.value = "<span style='color:red'><b>Errado!</b></span>"

sim.on_click(resposta_sim)
nao.on_click(resposta_nao)

display(widgets.HBox([pergunta, sim, nao]))
display(resultado)
# Out:
# ...
# HTML(value='')

# %%
import ipywidgets as widgets
from IPython.display import display

pergunta = widgets.HTML(
    value="<b>378 é um Número de Smith?</b>"
)

sim = widgets.Button(description="Sim")
nao = widgets.Button(description="Não")

resultado = widgets.HTML()

def resposta_sim(b):
    resultado.value = "<span style='color:green'><b>Correto!</b></span>"

def resposta_nao(b):
    resultado.value = "<span style='color:red'><b>Errado!</b></span>"

sim.on_click(resposta_sim)
nao.on_click(resposta_nao)

display(widgets.HBox([pergunta, sim, nao]))
display(resultado)
# Out:
# ...
# HTML(value='')

# %% [markdown]
# <h1 id="conceitos">Conceitos Fundamentais</h1>

# %% [markdown]
# <h1 id="interativos">Exercícios Interativos</h1>

# %%
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

smith_data = [
    (4, "2 x 2", 4, "2 + 2 = 4"), (22, "2 * 11", 4, "2 + 1 + 1 = 4"), (27, "3 * 3 * 3", 9, "3 + 3 + 3 = 9"),
    (58, "2 * 29", 13, "2 + 2 + 9 = 13"), (85, "5 * 17", 13, "5 + 1 + 7 = 13"), (94, "2 * 47", 13, "2 + 4 + 7 = 13"),
    (121, "11 * 11", 4, "1 + 1 + 1 + 1 = 4"), (166, "2 * 83", 13, "2 + 8 + 3 = 13"), (202, "2 * 101", 4, "2 + 1 + 0 + 1 = 4"),
    (265, "5 * 53", 13, "5 + 5 + 3 = 13"), (274, "2 * 137", 13, "2 + 1 + 3 + 7 = 13"), (319, "11 * 29", 13, "1 + 1 + 2 + 9 = 13"),
    (346, "2 * 173", 13, "2 + 1 + 7 + 3 = 13"), (355, "5 * 71", 13, "5 + 7 + 1 = 13"), (378, "2 * 3 * 3 * 3 * 7", 18, "2 + 3 + 3 + 3 + 7 = 18"),
    (382, "2 * 191", 13, "2 + 1 + 9 + 1 = 13"), (391, "17 * 23", 13, "1 + 7 + 2 + 3 = 13"), (438, "2 * 3 * 73", 15, "2 + 3 + 7 + 3 = 15"),
    (454, "2 * 227", 13, "2 + 2 + 2 + 7 = 13"), (483, "3 * 7 * 23", 15, "3 + 7 + 2 + 3 = 15"), (517, "11 * 47", 13, "1 + 1 + 4 + 7 = 13"),
    (526, "2 * 263", 13, "2 + 2 + 6 + 3 = 13"), (535, "5 * 107", 13, "5 + 1 + 0 + 7 = 13"), (562, "2 * 281", 13, "2 + 2 + 8 + 1 = 13"),
    (576, "2^6 * 3^2", 18, "2+2+2+2+2+2 + 3+3 = 18"), (588, "2 * 2 * 3 * 7 * 7", 21, "2 + 2 + 3 + 7 + 7 = 21"), (627, "3 * 11 * 19", 15, "3 + 1 + 1 + 1 + 9 = 15"),
    (634, "2 * 317", 13, "2 + 3 + 1 + 7 = 13"), (636, "2 * 2 * 3 * 53", 15, "2 + 2 + 3 + 5 + 3 = 15"), (645, "3 * 5 * 43", 15, "3 + 5 + 4 + 3 = 15"),
    (648, "2³ * 3^4", 18, "2+2+2 + 3+3+3+3 = 18"), (654, "2 * 3 * 109", 15, "2 + 3 + 1 + 0 + 9 = 15"), (663, "3 * 13 * 17", 15, "3 + 1 + 3 + 1 + 7 = 15"),
    (666, "2 * 3 * 3 * 37", 18, "2 + 3 + 3 + 3 + 7 = 18"), (690, "2 * 3 * 5 * 23", 15, "2 + 3 + 5 + 2 + 3 = 15"), (706, "2 * 353", 13, "2 + 3 + 5 + 3 = 13"),
    (728, "2 * 2 * 2 * 7 * 13", 17, "2 + 2 + 2 + 7 + 1 + 3 = 17"), (729, "3^6", 18, "3 + 3 + 3 + 3 + 3 + 3 = 18"), (746, "2 * 373", 17, "2 + 3 + 7 + 3 = 17"),
    (762, "2 * 3 * 127", 15, "2 + 3 + 1 + 2 + 7 = 15"), (764, "2 * 2 * 191", 17, "2 + 2 + 1 + 9 + 1 = 17"), (777, "3 * 7 * 37", 21, "3 + 7 + 3 + 7 = 21"),
    (791, "7 * 113", 17, "7 + 1 + 1 + 3 = 17"), (804, "2 * 2 * 3 * 67", 12, "2 + 2 + 3 + 6 + 7 = 12"),
    (816, "2^4 * 3 * 17", 15, "2+2+2+2 + 3 + 1+7 = 15"),
    (820, "2 * 2 * 5 * 41", 10, "2 + 2 + 5 + 4 + 1 = 10"), (825, "3 * 5 * 5 * 11", 15, "3 + 5 + 5 + 1 + 1 = 15"), (849, "3 * 283", 21, "3 + 2 + 8 + 3 = 21"),
    (866, "2 * 433", 20, "2 + 4 + 3 + 3 = 20")
]

output_superior = widgets.Output()

def atualizar_painel_superior(index_selecionado):
    num, fatoracao, soma_num, soma_fat = smith_data[index_selecionado]
    posicao = index_selecionado + 1

    html_content = f"""
    <div style="background-color: #f7fafc; border: 1px solid #e2e8f0; border-left: 6px solid #3182ce; padding: 15px; border-radius: 8px; margin-bottom: 15px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;">
        <h3 style="margin: 0 0 10px 0; color: #2b6cb0;">{posicao} Número de Smith: <span style="font-size: 28px; font-weight: bold; color: #1a202c;">{num}</span></h3>
        <p style="margin: 6px 0; font-size: 15px;"><b>Fatoração Prima:</b> <code style="font-size: 15px; background: #edf2f7; padding: 3px 8px; border-radius: 4px; color: #2d3748;">{fatoracao}</code></p>
        <p style="margin: 6px 0; font-size: 15px;"><b>Soma dos Algarismos:</b> <span style="color: #3182ce; font-weight: bold;">{soma_num}</span></p>
</div>
    """
    with output_superior:
        clear_output(wait=True)
        display(HTML(html_content))

botoes = []
for idx, (num, *_) in enumerate(smith_data):
    btn = widgets.Button(
        description=str(num),
        layout=widgets.Layout(width='70px', height='45px', margin='3px'),
        style={'font_weight': 'bold'}
    )
    btn.index_data = idx

    def ao_clicar(b):
        atualizar_painel_superior(b.index_data)

    btn.on_click(ao_clicar)
    botoes.append(btn)

linhas_grade = [widgets.HBox(botoes[i:i+7]) for i in range(0, 49, 7)]
grade_quadrada = widgets.VBox(linhas_grade)

atualizar_painel_superior(0)

display(output_superior)
display(widgets.HTML("<p style='font-family: sans-serif; font-weight: bold; margin: 10px 0 5px 0; color: #4a5568;'>Clique em um número para ver os detalhes acima:</p>"))
display(grade_quadrada)
# Out:
# Output()
# HTML(value="<p style='font-family: sans-serif; font-weight: bold; margin: 10px 0 5px 0; color: #4a5568;'>Cliqu…
# ...

# %% [markdown]
# <h1 id="compartilhe">Compartilhe sua ideia</h1>

# %% [markdown]
# Ao longo deste material, você explorou padrões, analisou exemplos, formulou conjecturas e buscou compreender propriedades desses números especiais. Talvez, durante esse processo, você tenha encontrado uma nova regularidade, elaborado uma demonstração diferente, identificado uma generalização ou levantado uma questão que ainda merece investigação. Se desejar contribuir com o desenvolvimento deste tema, compartilhe suas ideias. Serão muito bem-vindas novas conjecturas, demonstrações, generalizações, exemplos interessantes ou sugestões.
#
# Envie sua contribuição para:
# - monikyoliveira@outlook.com
#
# A Matemática é construída coletivamente. Cada nova observação tem o potencial de ampliar nossa compreensão e inspirar futuras investigações.
