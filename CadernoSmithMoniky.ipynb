# %%
import panel as pn
pn.extension(comms='colab')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a6938d05-7218-4ddc-880b-62789f0b408d'>
#   <div id="b775cde1-d79c-4777-906a-803ee1868a7d" data-root-id="a6938d05-7218-4ddc-880b-62789f0b408d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Números de Smith
# ## Explorando relações e padrões numéricos

# %% [markdown]
# # Sumário
#
# - <a href="#investigacao">Investigação Inicial</a>
#
# - <a href="#historia">História dos Números de Smith</a>
#
# - <a href="#video">Vídeo</a>
#
# - <a href="#exercicios">Exercícios Básicos</a>
#
# - <a href="#conceitos">Conceitos Fundamentais</a>
#
# - <a href="#interativos">Exercícios Interativos</a>
#
# - <a href="#compartilhe">Compartilhe sua ideia</a>
#
# - <a href="#complementar">Materiais Complementares</a>
#
# - <a href="#referencia">Referências</a>

# %% [markdown]
# <h1 id="investigacao">Investigação Inicial</h1>

# %% [markdown]
# Observe o número 666 e sua fatoração em números primos.
#
# | Número | Fatoração |
# |:------:|:---------:|
# | 666  | 2 x 3 x 3 x 37     |
#
# - O que você percebe?
# - Existe alguma relação entre os algarismos do número e dos fatores primos?
#
# <details>
# <summary style="font-size:18px; color:#0B3B70;">
# <b>Ver resposta</b>
# </summary>
#
# <div style="
# margin-top:10px;
# padding:15px;
# background:#eef6ff;
# border-left:5px solid #0B3B70;
# border-radius:8px;
# ">
#
# A relação encontrada é que:
#
# <ul>
# <li>A soma dos algarismos do número (6+6+6) é 18.</li>
# <li>A soma dos algarismos de seus fatores primos (2+3+3+3+7) também é 18.</li>
# </ul>
# </div>
# </details>

# %% [markdown]
# <h1 id="historia">História dos Números de Smith</h1>

# %% [markdown]
# Na Matemática, muitas descobertas começaram justamente com uma simples observação do cotidiano. Um exemplo disso ocorreu em 1982, quando o matemático canadense-americano Albert Wilansky observou o número de telefone de seu cunhado, Harold Smith: 493-7775. Ele notou que ao fatorar este número, a soma dos algarismos do número se igualava a soma dos algarismos de seus fatores primos.
#
# ![Apresenta1.jpg](data:image/jpeg;base64,...)
#
# Wilansky cunhou o termo "número de Smith" em homenagem a Harold Smith. Essa observação deu origem ao estudo dessa classe especial de números.

# %% [markdown]
# <h1 id="video">Vídeo</h1>

# %%
from IPython.display import Video

Video("video.mp4", embed=True)

Video("/content/video.mp4", embed=True, width=900)
# Out:
# <video controls  width="900" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# <h1 id="exercicios">Exercícios Básicos</h1>

# %% [markdown]
# Complete as etapas abaixo para investigar se o número apresentado é um número de Smith. Preencha a fatoração prima, calcule as somas dos algarismos e, ao final, registre sua conclusão.

# %%
# @title Exercício - Número 85

import ipywidgets as widgets
from IPython.display import display, HTML

# ---------- Título ----------
display(HTML("""
<h2 style="color:#2E86DE;">
Complete os espaços
</h2>
<p>Preencha corretamente todas as informações sobre o número <b>85</b>.</p>
"""))

# ---------- Campos ----------
f1_85 = widgets.Text(layout=widgets.Layout(width='55px'))
f2_85 = widgets.Text(layout=widgets.Layout(width='55px'))

d1_85 = widgets.Text(layout=widgets.Layout(width='45px'))
d2_85 = widgets.Text(layout=widgets.Layout(width='45px'))
d3_85 = widgets.Text(layout=widgets.Layout(width='45px'))

soma1_85 = widgets.Text(layout=widgets.Layout(width='55px'))

n1_85 = widgets.Text(layout=widgets.Layout(width='45px'))
n2_85 = widgets.Text(layout=widgets.Layout(width='45px'))

soma2_85 = widgets.Text(layout=widgets.Layout(width='55px'))

smith_85 = widgets.RadioButtons(
    options=['Smith','Não Smith'],
    layout=widgets.Layout(width='170px')
)

botao_85 = widgets.Button(
    description='✔ Verificar',
    button_style='success'
)

saida_85 = widgets.Output()

# ---------- Função para colorir ----------
def pintar_85(campo, correto):
    campo.layout.border = '3px solid green' if correto else '3px solid red'

# ---------- Correção ----------
def verificar_85(b):

    corretos = 0

    respostas = [

        (f1_85,"5"),
        (f2_85,"17"),

        (d1_85,"5"),
        (d2_85,"1"),
        (d3_85,"7"),
        (soma1_85,"13"),

        (n1_85,"8"),
        (n2_85,"5"),
        (soma2_85,"13")

    ]

    for campo, resposta in respostas:

        ok = campo.value.strip() == resposta
        pintar_85(campo, ok)

        if ok:
            corretos += 1

    if smith_85.value == "Smith":
        corretos += 1

    with saida_85:

        saida_85.clear_output()

        if corretos == 10:

            display(HTML("""
            <div style="
            background:#d4edda;
            color:#155724;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            🎉 Parabéns! Você acertou tudo!
            </div>
            """))

        else:

            display(HTML(f"""
            <div style="
            background:#f8d7da;
            color:#721c24;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            Você acertou <b>{corretos}</b> de 10 respostas.
            </div>
            """))

botao_85.on_click(verificar_85)

# ---------- Exercício ----------

display(HTML("<h3>85 = </h3>"))

display(widgets.HBox([
    f1_85,
    widgets.Label("×"),
    f2_85
]))

display(HTML("<br><b>Soma dos dígitos dos fatores:</b>"))

display(widgets.HBox([
    d1_85,
    widgets.Label("+"),
    d2_85,
    widgets.Label("+"),
    d3_85,
    widgets.Label("="),
    soma1_85
]))

display(HTML("<br><b>Soma dos dígitos do número:</b>"))

display(widgets.HBox([
    n1_85,
    widgets.Label("+"),
    n2_85,
    widgets.Label("="),
    soma2_85
]))

display(HTML("<br><b>85 é um número de Smith?</b>"))

display(smith_85)

display(botao_85)

display(saida_85)
# Out:
# <h2 style="color:#2E86DE;">
# Complete os espaços
# </h2>
# <p>Preencha corretamente todas as informações sobre o número <b>85</b>.</p>
# <h3>85 = </h3>
# ...
# <br><b>Soma dos dígitos dos fatores:</b>
# ...
# <br><b>Soma dos dígitos do número:</b>
# ...
# <br><b>85 é um número de Smith?</b>
# RadioButtons(layout=Layout(width='170px'), options=('Smith', 'Não Smith'), value='Smith')
# Button(button_style='success', description='✔ Verificar', style=ButtonStyle())
# Output()

# %%
# @title Exercício - Número 198

import ipywidgets as widgets
from IPython.display import display, HTML

# ---------- Título ----------
display(HTML("""
<h2 style="color:#2E86DE;">
Complete os espaços
</h2>
<p>Preencha corretamente todas as informações sobre o número <b>198</b>.</p>
"""))

# ---------- Campos ----------
f1_198 = widgets.Text(layout=widgets.Layout(width='55px'))
f2_198 = widgets.Text(layout=widgets.Layout(width='55px'))
f3_198 = widgets.Text(layout=widgets.Layout(width='55px'))
f4_198 = widgets.Text(layout=widgets.Layout(width='55px'))

d1_198 = widgets.Text(layout=widgets.Layout(width='45px'))
d2_198 = widgets.Text(layout=widgets.Layout(width='45px'))
d3_198 = widgets.Text(layout=widgets.Layout(width='45px'))
d4_198 = widgets.Text(layout=widgets.Layout(width='45px'))
d5_198 = widgets.Text(layout=widgets.Layout(width='45px'))

soma1_198 = widgets.Text(layout=widgets.Layout(width='55px'))

n1_198 = widgets.Text(layout=widgets.Layout(width='45px'))
n2_198 = widgets.Text(layout=widgets.Layout(width='45px'))
n3_198 = widgets.Text(layout=widgets.Layout(width='45px'))

soma2_198 = widgets.Text(layout=widgets.Layout(width='55px'))

smith_198 = widgets.RadioButtons(
    options=['Smith','Não Smith'],
    layout=widgets.Layout(width='170px')
)

botao_198 = widgets.Button(
    description='✔ Verificar',
    button_style='success'
)

saida_198 = widgets.Output()

# ---------- Função para colorir ----------
def pintar_198(campo, correto):
    if correto:
        campo.layout.border = '3px solid green'
    else:
        campo.layout.border = '3px solid red'

# ---------- Correção ----------
def verificar_198(b):

    corretos = 0

    respostas = [

        (f1_198,"2"),
        (f2_198,"3"),
        (f3_198,"3"),
        (f4_198,"11"),

        (d1_198,"2"),
        (d2_198,"3"),
        (d3_198,"3"),
        (d4_198,"1"),
        (d5_198,"1"),
        (soma1_198,"10"),

        (n1_198,"1"),
        (n2_198,"9"),
        (n3_198,"8"),
        (soma2_198,"18")

    ]

    for campo, resposta in respostas:

        ok = campo.value.strip() == resposta

        pintar_198(campo, ok)

        if ok:
            corretos += 1

    if smith_198.value == "Não Smith":
        corretos += 1

    with saida_198:

        saida_198.clear_output()

        if corretos == 15:

            display(HTML("""
            <div style="
            background:#d4edda;
            color:#155724;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            🎉 Parabéns! Você acertou tudo!
            </div>
            """))

        else:

            display(HTML(f"""
            <div style="
            background:#f8d7da;
            color:#721c24;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            Você acertou <b>{corretos}</b> de 15 respostas.
            </div>
            """))

botao_198.on_click(verificar_198)

# ---------- Exercício ----------

display(HTML("<h3>198 = </h3>"))

display(widgets.HBox([
    f1_198,
    widgets.Label("×"),
    f2_198,
    widgets.Label("×"),
    f3_198,
    widgets.Label("×"),
    f4_198
]))

display(HTML("<br><b>Soma dos dígitos dos fatores:</b>"))

display(widgets.HBox([
    d1_198,
    widgets.Label("+"),
    d2_198,
    widgets.Label("+"),
    d3_198,
    widgets.Label("+"),
    d4_198,
    widgets.Label("+"),
    d5_198,
    widgets.Label("="),
    soma1_198
]))

display(HTML("<br><b>Soma dos dígitos do número:</b>"))

display(widgets.HBox([
    n1_198,
    widgets.Label("+"),
    n2_198,
    widgets.Label("+"),
    n3_198,
    widgets.Label("="),
    soma2_198
]))

display(HTML("<br><b>198 é um número de Smith?</b>"))

display(smith_198)

display(botao_198)

display(saida_198)
# Out:
# <h2 style="color:#2E86DE;">
# Complete os espaços
# </h2>
# <p>Preencha corretamente todas as informações sobre o número <b>198</b>.</p>
# <h3>198 = </h3>
# ...
# <br><b>Soma dos dígitos dos fatores:</b>
# ...
# <br><b>Soma dos dígitos do número:</b>
# ...
# <br><b>198 é um número de Smith?</b>
# RadioButtons(layout=Layout(width='170px'), options=('Smith', 'Não Smith'), value='Smith')
# Button(button_style='success', description='✔ Verificar', style=ButtonStyle())
# Output()

# %%
# @title Exercício - Número 250

import ipywidgets as widgets
from IPython.display import display, HTML

# ---------- Título ----------
display(HTML("""
<h2 style="color:#2E86DE;">
Complete os espaços
</h2>
<p>Preencha corretamente todas as informações sobre o número <b>250</b>.</p>
"""))

# ---------- Campos ----------
f1_250 = widgets.Text(layout=widgets.Layout(width='55px'))
f2_250 = widgets.Text(layout=widgets.Layout(width='55px'))
f3_250 = widgets.Text(layout=widgets.Layout(width='55px'))
f4_250 = widgets.Text(layout=widgets.Layout(width='55px'))

d1_250 = widgets.Text(layout=widgets.Layout(width='45px'))
d2_250 = widgets.Text(layout=widgets.Layout(width='45px'))
d3_250 = widgets.Text(layout=widgets.Layout(width='45px'))
d4_250 = widgets.Text(layout=widgets.Layout(width='45px'))

soma1_250 = widgets.Text(layout=widgets.Layout(width='55px'))

n1_250 = widgets.Text(layout=widgets.Layout(width='45px'))
n2_250 = widgets.Text(layout=widgets.Layout(width='45px'))
n3_250 = widgets.Text(layout=widgets.Layout(width='45px'))

soma2_250 = widgets.Text(layout=widgets.Layout(width='55px'))

smith_250 = widgets.RadioButtons(
    options=['Smith','Não Smith'],
    layout=widgets.Layout(width='170px')
)

botao_250 = widgets.Button(
    description='✔ Verificar',
    button_style='success'
)

saida_250 = widgets.Output()

# ---------- Função para colorir ----------
def pintar_250(campo, correto):
    if correto:
        campo.layout.border = '3px solid green'
    else:
        campo.layout.border = '3px solid red'

# ---------- Correção ----------
def verificar_250(b):

    corretos = 0

    respostas = [

        (f1_250,"2"),
        (f2_250,"5"),
        (f3_250,"5"),
        (f4_250,"5"),

        (d1_250,"2"),
        (d2_250,"5"),
        (d3_250,"5"),
        (d4_250,"5"),
        (soma1_250,"17"),

        (n1_250,"2"),
        (n2_250,"5"),
        (n3_250,"0"),
        (soma2_250,"7")

    ]

    for campo, resposta in respostas:

        ok = campo.value.strip() == resposta

        pintar_250(campo, ok)

        if ok:
            corretos += 1

    if smith_250.value == "Não Smith":
        corretos += 1

    with saida_250:

        saida_250.clear_output()

        if corretos == 14:

            display(HTML("""
            <div style="
            background:#d4edda;
            color:#155724;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            🎉 Parabéns! Você acertou tudo!
            </div>
            """))

        else:

            display(HTML(f"""
            <div style="
            background:#f8d7da;
            color:#721c24;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            Você acertou <b>{corretos}</b> de 14 respostas.
            </div>
            """))

botao_250.on_click(verificar_250)

# ---------- Exercício ----------

display(HTML("<h3>250 = </h3>"))

display(widgets.HBox([
    f1_250,
    widgets.Label("×"),
    f2_250,
    widgets.Label("×"),
    f3_250,
    widgets.Label("×"),
    f4_250
]))

display(HTML("<br><b>Soma dos dígitos dos fatores:</b>"))

display(widgets.HBox([
    d1_250,
    widgets.Label("+"),
    d2_250,
    widgets.Label("+"),
    d3_250,
    widgets.Label("+"),
    d4_250,
    widgets.Label("="),
    soma1_250
]))

display(HTML("<br><b>Soma dos dígitos do número:</b>"))

display(widgets.HBox([
    n1_250,
    widgets.Label("+"),
    n2_250,
    widgets.Label("+"),
    n3_250,
    widgets.Label("="),
    soma2_250
]))

display(HTML("<br><b>250 é um número de Smith?</b>"))

display(smith_250)

display(botao_250)

display(saida_250)
# Out:
# <h2 style="color:#2E86DE;">
# Complete os espaços
# </h2>
# <p>Preencha corretamente todas as informações sobre o número <b>250</b>.</p>
# <h3>250 = </h3>
# ...
# <br><b>Soma dos dígitos dos fatores:</b>
# ...
# <br><b>Soma dos dígitos do número:</b>
# ...
# <br><b>250 é um número de Smith?</b>
# RadioButtons(layout=Layout(width='170px'), options=('Smith', 'Não Smith'), value='Smith')
# Button(button_style='success', description='✔ Verificar', style=ButtonStyle())
# Output()

# %%
# @title Exercício - Número 378

import ipywidgets as widgets
from IPython.display import display, HTML

# ---------- Título ----------
display(HTML("""
<h2 style="color:#2E86DE;">
Complete os espaços
</h2>
<p>Preencha corretamente todas as informações sobre o número <b>378</b>.</p>
"""))

# ---------- Campos ----------
f1_378 = widgets.Text(layout=widgets.Layout(width='55px'))
f2_378 = widgets.Text(layout=widgets.Layout(width='55px'))
f3_378 = widgets.Text(layout=widgets.Layout(width='55px'))
f4_378 = widgets.Text(layout=widgets.Layout(width='55px'))
f5_378 = widgets.Text(layout=widgets.Layout(width='55px'))

d1_378 = widgets.Text(layout=widgets.Layout(width='45px'))
d2_378 = widgets.Text(layout=widgets.Layout(width='45px'))
d3_378 = widgets.Text(layout=widgets.Layout(width='45px'))
d4_378 = widgets.Text(layout=widgets.Layout(width='45px'))
d5_378 = widgets.Text(layout=widgets.Layout(width='45px'))

soma1_378 = widgets.Text(layout=widgets.Layout(width='55px'))

n1_378 = widgets.Text(layout=widgets.Layout(width='45px'))
n2_378 = widgets.Text(layout=widgets.Layout(width='45px'))
n3_378 = widgets.Text(layout=widgets.Layout(width='45px'))

soma2_378 = widgets.Text(layout=widgets.Layout(width='55px'))

smith_378 = widgets.RadioButtons(
    options=['Smith','Não Smith'],
    layout=widgets.Layout(width='170px')
)

botao_378 = widgets.Button(
    description='✔ Verificar',
    button_style='success'
)

saida_378 = widgets.Output()

# ---------- Função para colorir ----------
def pintar_378(campo, correto):
    campo.layout.border = '3px solid green' if correto else '3px solid red'

# ---------- Correção ----------
def verificar_378(b):

    corretos = 0

    respostas = [

        (f1_378,"2"),
        (f2_378,"3"),
        (f3_378,"3"),
        (f4_378,"3"),
        (f5_378,"7"),

        (d1_378,"2"),
        (d2_378,"3"),
        (d3_378,"3"),
        (d4_378,"3"),
        (d5_378,"7"),
        (soma1_378,"18"),

        (n1_378,"3"),
        (n2_378,"7"),
        (n3_378,"8"),
        (soma2_378,"18")

    ]

    for campo, resposta in respostas:

        ok = campo.value.strip() == resposta
        pintar_378(campo, ok)

        if ok:
            corretos += 1

    if smith_378.value == "Smith":
        corretos += 1

    with saida_378:

        saida_378.clear_output()

        if corretos == 16:

            display(HTML("""
            <div style="
            background:#d4edda;
            color:#155724;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            🎉 Parabéns! Você acertou tudo!
            </div>
            """))

        else:

            display(HTML(f"""
            <div style="
            background:#f8d7da;
            color:#721c24;
            padding:15px;
            border-radius:10px;
            font-size:18px;">
            Você acertou <b>{corretos}</b> de 16 respostas.
            </div>
            """))

botao_378.on_click(verificar_378)

# ---------- Exercício ----------

display(HTML("<h3>378 = </h3>"))

display(widgets.HBox([
    f1_378,
    widgets.Label("×"),
    f2_378,
    widgets.Label("×"),
    f3_378,
    widgets.Label("×"),
    f4_378,
    widgets.Label("×"),
    f5_378
]))

display(HTML("<br><b>Soma dos dígitos dos fatores:</b>"))

display(widgets.HBox([
    d1_378,
    widgets.Label("+"),
    d2_378,
    widgets.Label("+"),
    d3_378,
    widgets.Label("+"),
    d4_378,
    widgets.Label("+"),
    d5_378,
    widgets.Label("="),
    soma1_378
]))

display(HTML("<br><b>Soma dos dígitos do número:</b>"))

display(widgets.HBox([
    n1_378,
    widgets.Label("+"),
    n2_378,
    widgets.Label("+"),
    n3_378,
    widgets.Label("="),
    soma2_378
]))

display(HTML("<br><b>378 é um número de Smith?</b>"))

display(smith_378)

display(botao_378)

display(saida_378)
# Out:
# <h2 style="color:#2E86DE;">
# Complete os espaços
# </h2>
# <p>Preencha corretamente todas as informações sobre o número <b>378</b>.</p>
# <h3>378 = </h3>
# ...
# <br><b>Soma dos dígitos dos fatores:</b>
# ...
# <br><b>Soma dos dígitos do número:</b>
# ...
# <br><b>378 é um número de Smith?</b>
# RadioButtons(layout=Layout(width='170px'), options=('Smith', 'Não Smith'), value='Smith')
# Button(button_style='success', description='✔ Verificar', style=ButtonStyle())
# Output()

# %% [markdown]
# <h1 id="conceitos">Conceitos Fundamentais</h1>

# %% [markdown]
# Um número de Smith é um número composto n tal que a soma dos seus algarismos na base decimal é igual a soma dos algarismos de todos os seus fatores primos, contados com multiplicidade.
#
# Vamos denotar como s(m) a soma dos algarismos do número m e s_p(m) soma dos algarismos de todos os fatores primos de m. Por exemplo, 58 = 2 × 29 e s(58) = 13 = 2 + (2 + 9) = s_p(58). Portanto, 58 é um número de Smith.
#
# Diversos acadêmicos estudaram os números de Smith e encontraram algumas propriedades interessantes que servem de base para descoberta de novos números de Smith. Cito aqui duas de grande relevância.
#
# 1.   Para qualquer número inteiro positivo m tem-se s(m) ≡ m mod 9.
# 2.   Seja m e n números inteiros positivos, então sp(mn) = sp(m) + sp(n).
#
# Ainda não há uma generalização dos números de Smith, ou seja, uma fórmula que nos permita encontrar qualquer um deles, entretanto desde o artigo de Wilansky várias proposições surgiram para encontrar números de Smith. Como:
#
# *   Seja p um número primo, com p > 5 e s(p) = 5. Então 21p e 112p são números de Smith.
# *   Seja n um número inteiro positivo tal que s(n) > sp(n) e s(n) ≡ sp(n) mod 7. Então 10kn é um número de Smith, onde k = (s(n) − sp(n))/7.
# *   Seja p um número primo composto dos algarismos 0, 1, 2, 3 e s(p) = 13. Então 11.001p é um número de Smith.
# *   Seja p um número primo composto dos algarismos 0, 1, 2, 3 e s(p) = 11. Então 101.001p é um número de Smith
# *   Seja p um número primo maior que 101 contendo apenas os algarismos 0, 1, 2, 3, 4 e s(p) = 7n + 2 com n ≥ 1 . Então 10n × 11p e 10n × 101p são números de Smith.
# *   Seja Rm um número primo. Então 3.304Rm, com m ≥ 3, é um número de Smith.
# *   Seja q um primo cujos algarismos são apenas 0 ou 1. Então existe um múltiplo de q que é um número de Smith.
# *   Seja n um número primo então 2n é um número de Smith se, e somente se, s(2n) − s(n) = 2.
#
# Quando Wilansky publicou o primeiro artigo sobre o tema, levantou o questionamento sobre a infinitude desse conjunto. Poucos anos depois, foi demonstrado que  McDaniel conseguiu resultados que responderam positivamente a esta questão.

# %% [markdown]
# <h1 id="interativos">Exercícios Interativos</h1>

# %% [markdown]
# A tabela abaixo apresenta os 49 primeiros números de Smith, suas fatorações primas e as somas dos algarismos.

# %%
# @title
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

smith_data = [
    (4, "2²", 4, "2 + 2 = 4"), (22, "2 x 11", 4, "2 + 1 + 1 = 4"), (27, "3³", 9, "3 + 3 + 3 = 9"),
    (58, "2 x 29", 13, "2 + 2 + 9 = 13"), (85, "5 x 17", 13, "5 + 1 + 7 = 13"), (94, "2 x 47", 13, "2 + 4 + 7 = 13"),
    (121, "11²", 4, "1 + 1 + 1 + 1 = 4"), (166, "2 x 83", 13, "2 + 8 + 3 = 13"), (202, "2 x 101", 4, "2 + 1 + 0 + 1 = 4"),
    (265, "5 x 53", 13, "5 + 5 + 3 = 13"), (274, "2 x 137", 13, "2 + 1 + 3 + 7 = 13"), (319, "11 x 29", 13, "1 + 1 + 2 + 9 = 13"),
    (346, "2 x 173", 13, "2 + 1 + 7 + 3 = 13"), (355, "5 x 71", 13, "5 + 7 + 1 = 13"), (378, "2 x 3³ x 7", 18, "2 + 3 + 3 + 3 + 7 = 18"),
    (382, "2 x 191", 13, "2 + 1 + 9 + 1 = 13"), (391, "17 x 23", 13, "1 + 7 + 2 + 3 = 13"), (438, "2 x 3 x 73", 15, "2 + 3 + 7 + 3 = 15"),
    (454, "2 x 227", 13, "2 + 2 + 2 + 7 = 13"), (483, "3 x 7 x 23", 15, "3 + 7 + 2 + 3 = 15"), (517, "11 x 47", 13, "1 + 1 + 4 + 7 = 13"),
    (526, "2 x 263", 13, "2 + 2 + 6 + 3 = 13"), (535, "5 x 107", 13, "5 + 1 + 0 + 7 = 13"), (562, "2 x 281", 13, "2 + 2 + 8 + 1 = 13"),
    (576, "2^6 x 3²", 18, "2+2+2+2+2+2 + 3+3 = 18"), (588, "2² x 3 x 7²", 21, "2 + 2 + 3 + 7 + 7 = 21"), (627, "3 x 11 x 19", 15, "3 + 1 + 1 + 1 + 9 = 15"),
    (634, "2 x 317", 13, "2 + 3 + 1 + 7 = 13"), (636, "2² x 3 x 53", 15, "2 + 2 + 3 + 5 + 3 = 15"), (645, "3 x 5 x 43", 15, "3 + 5 + 4 + 3 = 15"),
    (648, "2³ x 3^4", 18, "2+2+2 + 3+3+3+3 = 18"), (654, "2 x 3 x 109", 15, "2 + 3 + 1 + 0 + 9 = 15"), (663, "3 x 13 x 17", 15, "3 + 1 + 3 + 1 + 7 = 15"),
    (666, "2 x 3² x 37", 18, "2 + 3 + 3 + 3 + 7 = 18"), (690, "2 x 3 x 5 x 23", 15, "2 + 3 + 5 + 2 + 3 = 15"), (706, "2 x 353", 13, "2 + 3 + 5 + 3 = 13"),
    (728, "2³ x 7 x 13", 17, "2 + 2 + 2 + 7 + 1 + 3 = 17"), (729, "3^6", 18, "3 + 3 + 3 + 3 + 3 + 3 = 18"), (746, "2 x 373", 17, "2 + 3 + 7 + 3 = 17"),
    (762, "2 x 3 x 127", 15, "2 + 3 + 1 + 2 + 7 = 15"), (764, "2² x 191", 17, "2 + 2 + 1 + 9 + 1 = 17"), (777, "3 x 7 x 37", 21, "3 + 7 + 3 + 7 = 21"),
    (791, "7 x 113", 17, "7 + 1 + 1 + 3 = 17"), (804, "2² x 3 x 67", 12, "2 + 2 + 3 + 6 + 7 = 12"),
    (816, "2^4 x 3 x 17", 15, "2+2+2+2 + 3 + 1+7 = 15"),
    (820, "2² x 5 x 41", 10, "2 + 2 + 5 + 4 + 1 = 10"), (825, "3 x 5² x 11", 15, "3 + 5 + 5 + 1 + 1 = 15"), (849, "3 x 283", 21, "3 + 2 + 8 + 3 = 21"),
    (866, "2 x 433", 20, "2 + 4 + 3 + 3 = 20")
]

output_superior = widgets.Output()

def atualizar_painel_superior(index_selecionado):
    num, fatoracao, soma_num, soma_fat = smith_data[index_selecionado]
    posicao = index_selecionado + 1

    html_content = f"""
    <div style="background-color: #f7fafc; border: 1px solid #e2e8f0; border-left: 6px solid #3182ce; padding: 15px; border-radius: 8px; margin-bottom: 15px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif;">
        <h3 style="margin: 0 0 10px 0; color: #2b6cb0;">{posicao} Número de Smith: <span style="font-size: 28px; font-weight: bold; color: #1a202c;">{num}</span></h3>
        <p style="margin: 6px 0; font-size: 15px;"><b>Fatoração Prima:</b> <code style="font-size: 15px; background: #edf2f7; padding: 3px 8px; border-radius: 4px; color: #2d3748;">{fatoracao}</code></p>
        <p style="margin: 6px 0; font-size: 15px;"><b>Soma dos Algarismos:</b> <span style="color: #3182ce; font-weight: bold;">{soma_num}</span></p>
</div>
    """
    with output_superior:
        clear_output(wait=True)
        display(HTML(html_content))

botoes = []
for idx, (num, *_) in enumerate(smith_data):
    btn = widgets.Button(
        description=str(num),
        layout=widgets.Layout(width='70px', height='45px', margin='3px'),
        style={'font_weight': 'bold'}
    )
    btn.index_data = idx

    def ao_clicar(b):
        atualizar_painel_superior(b.index_data)

    btn.on_click(ao_clicar)
    botoes.append(btn)

linhas_grade = [widgets.HBox(botoes[i:i+7]) for i in range(0, 49, 7)]
grade_quadrada = widgets.VBox(linhas_grade)

atualizar_painel_superior(0)

display(output_superior)
display(widgets.HTML("<p style='font-family: sans-serif; font-weight: bold; margin: 10px 0 5px 0; color: #4a5568;'>Clique em um número para ver os detalhes acima:</p>"))
display(grade_quadrada)
# Out:
# Output()
# HTML(value="<p style='font-family: sans-serif; font-weight: bold; margin: 10px 0 5px 0; color: #4a5568;'>Cliqu…
# ...

# %%
# @title
import ipywidgets as widgets
from IPython.display import display, HTML

# ==========================================================
# EXERCÍCIO 2.1
# ==========================================================

display(HTML("""
<h2 style="color:#2E86DE;">Exercício 2.1 – Descubra o erro</h2>

<p style="font-size:16px">
Leia atentamente a resolução abaixo e
<b>clique na linha que contém o erro.</b>
</p>
"""))

# ---------- Área de resposta ----------

saida1 = widgets.Output()

# ---------- Função ----------

def resposta1(correta):

    with saida1:

        saida1.clear_output()

        if correta:



            display(HTML("""
            <div style="
            background:#d4edda;
            border-left:8px solid #28a745;
            padding:15px;
            border-radius:8px;
            font-size:16px">

            <h3>✅ Muito bem!</h3>

            O erro está nesta linha.

            <br><br>

            Para verificar se um número é de Smith deve-se utilizar
            <b>a fatoração prima</b>.

            <br><br>

            Os números <b>6</b> e <b>63</b> são compostos.

            <br><br>

            A fatoração correta é:

            <h3>378 = 2 × 3 × 3 × 3 × 7</h3>

            </div>
            """))

        else:

            display(HTML("""
            <div style="
            background:#f8d7da;
            border-left:8px solid #dc3545;
            padding:15px;
            border-radius:8px;
            font-size:16px">

            ❌ Esta linha está correta.

            <br><br>

            Observe novamente a resolução.

            </div>
            """))

# ---------- Botões ----------

b1_1 = widgets.Button(
    description="Número: 378",
    layout=widgets.Layout(width="650px", height="42px")
)

b2_1 = widgets.Button(
    description="Fatoração: 378 = 6 × 63",
    layout=widgets.Layout(width="650px", height="42px")
)

b3_1 = widgets.Button(
    description="Soma dos algarismos dos fatores: 6 + 6 + 3 = 15",
    layout=widgets.Layout(width="650px", height="42px")
)

b4_1 = widgets.Button(
    description="Soma dos algarismos do número: 3 + 7 + 8 = 18",
    layout=widgets.Layout(width="650px", height="42px")
)

b5_1 = widgets.Button(
    description="Como 15 ≠ 18.",
    layout=widgets.Layout(width="650px", height="42px")
)

b6_1 = widgets.Button(
    description="378 não é um número de Smith.",
    layout=widgets.Layout(width="650px", height="42px")
)

# ---------- Eventos ----------

b1_1.on_click(lambda x: resposta1(False))
b2_1.on_click(lambda x: resposta1(True))
b3_1.on_click(lambda x: resposta1(False))
b4_1.on_click(lambda x: resposta1(False))
b5_1.on_click(lambda x: resposta1(False))
b6_1.on_click(lambda x: resposta1(False))

# ---------- Exibição ----------

display(b1_1)
display(b2_1)
display(b3_1)
display(b4_1)
display(b5_1)
display(b6_1)

display(saida1)
# Out:
# <h2 style="color:#2E86DE;">Exercício 2.1 – Descubra o erro</h2>
#
# <p style="font-size:16px">
# Leia atentamente a resolução abaixo e
# <b>clique na linha que contém o erro.</b>
# </p>
# Button(description='Número: 378', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='Fatoração: 378 = 6 × 63', layout=Layout(height='42px', width='650px'), style=ButtonStyle()…
# Button(description='Soma dos algarismos dos fatores: 6 + 6 + 3 = 15', layout=Layout(height='42px', width='650p…
# Button(description='Soma dos algarismos do número: 3 + 7 + 8 = 18', layout=Layout(height='42px', width='650px'…
# Button(description='Como 15 ≠ 18.', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='378 não é um número de Smith.', layout=Layout(height='42px', width='650px'), style=ButtonS…
# Output()

# %%
# @title
import ipywidgets as widgets
from IPython.display import display, HTML

# ==========================================================
# EXERCÍCIO 2.2
# ==========================================================

display(HTML("""
<h2 style="color:#2E86DE;">Exercício 2.2 – Descubra o erro</h2>

<p style="font-size:16px">
Leia atentamente a resolução abaixo e
<b>clique na linha que contém o erro.</b>
</p>
"""))

# ---------- Área de resposta ----------

saida2 = widgets.Output()

# ---------- Função ----------

def resposta2(correta):

    with saida2:

        saida2.clear_output()

        if correta:



            display(HTML("""
            <div style="
            background:#d4edda;
            border-left:8px solid #28a745;
            padding:15px;
            border-radius:8px;
            font-size:16px">

            <h3>✅ Muito bem!</h3>

            O erro está nesta linha.

            <br><br>

            Ao calcular a soma dos algarismos dos fatores primos,
            cada fator primo deve ser decomposto em seus algarismos.

            <br><br>

            O fator primo <b>11</b> deve contribuir com:

            <h3>1 + 1 = 2</h3>

            e não com <b>11</b>.

            <br><br>

            Portanto, a soma correta é:

            <h3>2 + 1 + 1 = 4</h3>

            Como a soma dos algarismos do número 22 também é
            <b>2 + 2 = 4</b>, concluímos que
            <b>22 é um número de Smith.</b>

            </div>
            """))

        else:

            display(HTML("""
            <div style="
            background:#f8d7da;
            border-left:8px solid #dc3545;
            padding:15px;
            border-radius:8px;
            font-size:16px">

            ❌ Esta linha está correta.

            <br><br>

            Observe novamente a resolução.

            </div>
            """))

# ---------- Botões ----------

b1_2 = widgets.Button(
    description="Número: 22",
    layout=widgets.Layout(width="650px", height="42px")
)

b2_2 = widgets.Button(
    description="Fatoração: 22 = 2 × 11",
    layout=widgets.Layout(width="650px", height="42px")
)

b3_2 = widgets.Button(
    description="Soma dos algarismos dos fatores: 2 + 11 = 13",
    layout=widgets.Layout(width="650px", height="42px")
)

b4_2 = widgets.Button(
    description="Soma dos algarismos do número: 2 + 2 = 4",
    layout=widgets.Layout(width="650px", height="42px")
)

b5_2 = widgets.Button(
    description="Como 13 ≠ 4.",
    layout=widgets.Layout(width="650px", height="42px")
)

b6_2 = widgets.Button(
    description="22 não é um número de Smith.",
    layout=widgets.Layout(width="650px", height="42px")
)

# ---------- Eventos ----------

b1_2.on_click(lambda x: resposta2(False))
b2_2.on_click(lambda x: resposta2(False))
b3_2.on_click(lambda x: resposta2(True))
b4_2.on_click(lambda x: resposta2(False))
b5_2.on_click(lambda x: resposta2(False))
b6_2.on_click(lambda x: resposta2(False))

# ---------- Exibição ----------

display(b1_2)
display(b2_2)
display(b3_2)
display(b4_2)
display(b5_2)
display(b6_2)

display(saida2)
# Out:
# <h2 style="color:#2E86DE;">Exercício 2.2 – Descubra o erro</h2>
#
# <p style="font-size:16px">
# Leia atentamente a resolução abaixo e
# <b>clique na linha que contém o erro.</b>
# </p>
# Button(description='Número: 22', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='Fatoração: 22 = 2 × 11', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='Soma dos algarismos dos fatores: 2 + 11 = 13', layout=Layout(height='42px', width='650px')…
# Button(description='Soma dos algarismos do número: 2 + 2 = 4', layout=Layout(height='42px', width='650px'), st…
# Button(description='Como 13 ≠ 4.', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='22 não é um número de Smith.', layout=Layout(height='42px', width='650px'), style=ButtonSt…
# Output()

# %%
# @title
import ipywidgets as widgets
from IPython.display import display, HTML

# ==========================================================
# EXERCÍCIO 2.3
# ==========================================================

display(HTML("""
<h2 style="color:#2E86DE;">Exercício 2.3 – Descubra o erro</h2>

<p style="font-size:16px">
Leia atentamente a resolução abaixo e
<b>clique na linha que contém o erro.</b>
</p>
"""))

# ---------- Área de resposta ----------

saida3 = widgets.Output()

# ---------- Função ----------

def resposta3(correta):

    with saida3:

        saida3.clear_output()

        if correta:



            display(HTML("""
            <div style="
            background:#d4edda;
            border-left:8px solid #28a745;
            padding:15px;
            border-radius:8px;
            font-size:16px">

            <h3>✅ Muito bem!</h3>

            O erro está nesta linha.

            <br><br>

            É verdade que a soma dos algarismos do número e a soma dos
            algarismos de seus fatores primos são iguais.

            <br><br>

            Entretanto, isso não é suficiente.

            <br><br>

            Pela definição, <b>todo número de Smith deve ser composto.</b>

            <br><br>

            Como <b>13 é um número primo</b>, ele não pode ser um número de Smith.

            </div>
            """))

        else:

            display(HTML("""
            <div style="
            background:#f8d7da;
            border-left:8px solid #dc3545;
            padding:15px;
            border-radius:8px;
            font-size:16px">

            ❌ Esta linha está correta.

            <br><br>

            Observe novamente a resolução.

            </div>
            """))

# ---------- Botões ----------

b1_3 = widgets.Button(
    description="Número: 13",
    layout=widgets.Layout(width="650px", height="42px")
)

b2_3 = widgets.Button(
    description="Fatoração: 13 = 13 (pois é um número primo)",
    layout=widgets.Layout(width="650px", height="42px")
)

b3_3 = widgets.Button(
    description="Soma dos algarismos dos fatores: 1 + 3 = 4",
    layout=widgets.Layout(width="650px", height="42px")
)

b4_3 = widgets.Button(
    description="Soma dos algarismos do número: 1 + 3 = 4",
    layout=widgets.Layout(width="650px", height="42px")
)

b5_3 = widgets.Button(
    description="Como 4 = 4.",
    layout=widgets.Layout(width="650px", height="42px")
)

b6_3 = widgets.Button(
    description="13 é um número de Smith.",
    layout=widgets.Layout(width="650px", height="42px")
)

# ---------- Eventos ----------

b1_3.on_click(lambda x: resposta3(False))
b2_3.on_click(lambda x: resposta3(False))
b3_3.on_click(lambda x: resposta3(False))
b4_3.on_click(lambda x: resposta3(False))
b5_3.on_click(lambda x: resposta3(False))
b6_3.on_click(lambda x: resposta3(True))

# ---------- Exibição ----------

display(b1_3)
display(b2_3)
display(b3_3)
display(b4_3)
display(b5_3)
display(b6_3)

display(saida3)
# Out:
# <h2 style="color:#2E86DE;">Exercício 2.3 – Descubra o erro</h2>
#
# <p style="font-size:16px">
# Leia atentamente a resolução abaixo e
# <b>clique na linha que contém o erro.</b>
# </p>
# Button(description='Número: 13', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='Fatoração: 13 = 13 (pois é um número primo)', layout=Layout(height='42px', width='650px'),…
# Button(description='Soma dos algarismos dos fatores: 1 + 3 = 4', layout=Layout(height='42px', width='650px'), …
# Button(description='Soma dos algarismos do número: 1 + 3 = 4', layout=Layout(height='42px', width='650px'), st…
# Button(description='Como 4 = 4.', layout=Layout(height='42px', width='650px'), style=ButtonStyle())
# Button(description='13 é um número de Smith.', layout=Layout(height='42px', width='650px'), style=ButtonStyle(…
# Output()

# %% [markdown]
# <h1 id="compartilhe">Compartilhe sua ideia</h1>

# %% [markdown]
# Ao longo deste material, você explorou padrões, analisou exemplos e  compreendeu propriedades desses números especiais. Talvez, durante esse processo, você tenha encontrado uma nova regularidade, elaborado uma demonstração diferente, identificado uma generalização ou levantado uma questão que ainda merece investigação. Se desejar contribuir com o desenvolvimento deste tema, compartilhe suas ideias. Serão muito bem-vindas novas conjecturas, demonstrações, generalizações, exemplos interessantes ou sugestões.
#
# Envie sua contribuição para:
# - monikyno@gmail.com
#
# A Matemática é construída coletivamente. Cada nova observação tem o potencial de ampliar nossa compreensão e inspirar futuras investigações.

# %% [markdown]
# <h1 id="complementar">Materiais Complementares</h1>

# %% [markdown]
# Páginas interessantes sobre números de Smith:
#
#
# https://www.primepuzzles.net/puzzles/puzz_108.htm
#
# https://www.shyamsundergupta.com/smith.htm

# %% [markdown]
# <h1 id="referencia">Referencias</h1>

# %% [markdown]
# Listar as referências do trabalho
